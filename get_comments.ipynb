# %%
import json
import requests
import pandas as pd
import argparse

# %%
api_key = json.loads(open("../API/YouTube/api_key.txt").read())['api_key']

# %%
def get_comments(videoId):

    #function that returns comments of a video given the videoId

    endpoint = '''https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId={}&key={}&maxResults=100&fields={}'''
    url = endpoint.format(videoId, api_key, 'items')

    response = json.loads(requests.get(url).text)

    return response

# %%
comment_metadata = get_comments('ztW7v-1FKxs')

# %%
comment_metadata
# Out:
# {'items': [{'kind': 'youtube#commentThread',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/_xGo4oGTag7oFkTEHp04BYcvR0k"',
#    'id': 'Ugxs7QJhPx5e8M9JWSR4AaABAg',
#    'snippet': {'videoId': 'ztW7v-1FKxs',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/7TlAZoRs_-_CzTJN2WokGxewwK8"',
#      'id': 'Ugxs7QJhPx5e8M9JWSR4AaABAg',
#      'snippet': {'authorDisplayName': 'a dash of ash',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-g1CQurtZs-k/AAAAAAAAAAI/AAAAAAAAAAA/bN_HbY4lI48/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCnoJo5BdCdNh7lGMytTZnzQ',
#       'authorChannelId': {'value': 'UCnoJo5BdCdNh7lGMytTZnzQ'},
#       'videoId': 'ztW7v-1FKxs',
# ...

# %%
items_list
# Out:
# [{'kind': 'youtube#commentThread',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/_xGo4oGTag7oFkTEHp04BYcvR0k"',
#   'id': 'Ugxs7QJhPx5e8M9JWSR4AaABAg',
#   'snippet': {'videoId': 'ztW7v-1FKxs',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/7TlAZoRs_-_CzTJN2WokGxewwK8"',
#     'id': 'Ugxs7QJhPx5e8M9JWSR4AaABAg',
#     'snippet': {'authorDisplayName': 'a dash of ash',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/-g1CQurtZs-k/AAAAAAAAAAI/AAAAAAAAAAA/bN_HbY4lI48/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCnoJo5BdCdNh7lGMytTZnzQ',
#      'authorChannelId': {'value': 'UCnoJo5BdCdNh7lGMytTZnzQ'},
#      'videoId': 'ztW7v-1FKxs',
# ...

# %%
items_list = comment_metadata['items']

# %%
len(items_list)
# Out:
# 32

# %%
def list_of_vid_comments(videoId):
    
    #function that takes videoId returns a list of comments from video in textOriginal 
    
    #list of all the comments and their metadata
    items_list = comment_metadata['items']
    
    list = []
    i = 0
    
    while i < len(items_list):
        #goes through the items_list and accesses the textOriginal
        comment_text = items_list[i]['snippet']['topLevelComment']['snippet']['textOriginal']
        #adds to list
        list.append(comment_text)
        i += 1

    return list

# %%
list_of_vid_comments(videoId)
# Out:
# ['Hey guys! Here’s the giveaway link! You can also find it in the description! Good luck!!💓\nEnter here https://go.epicreads.com/oppositeofalways-sweeps/ for a chance to win a copy of Opposite of Always and a set of three custom pennants. Sweepstakes sponsored by HarperCollins Publishers. US residents only. Ends 3/1/2019. Official Rules: https://d15fwz9jg1iq5f.cloudfront.net/wp-content/uploads/sites/2/2019/02/12155924/OppositeofAlwaysSweeps-OfficialRules.pdf #sponsored',
#  'My friend is giving me her chapter preview the red scrolls of magic from illumicrate and I’m so excited',
#  'Yes yes yes!!! Can’t wait to get my hands on The Steel Prince - I have stopped myself from buying the single issues because I wanted to buy them as a volume 😊 Also really looking forward to Sky Without Stars and I have pre-ordered Daisy Jones & The Six 🤗🌸',
#  'Super excited for the Red Scrolls of Magic! Also can’t wait for An Artless Demise by Anna Lee Huber.',
# ...
